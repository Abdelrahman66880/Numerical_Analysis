# %%
"""
Name: Abdelrahman Mohammed Fathi
ID: 120220215
Group: 2
sec: 3
CSE
"""

import numpy as np
import matplotlib.pyplot as plt

# TASK 1
x_1 = np.arange(1, 11)
y_1 = 2 * x_1 + 5

plt.plot(x_1, y_1, '-g', marker="o")
plt.title('Task 1: Linear Function')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# TASK 2
x_2 = np.linspace(0, 3 * np.pi, 1000)

plt.plot(x_2, np.sin(x_2), "-r")
plt.title('Task 2: Sine Function')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# TASK 3
x_3 = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11, 20, 51, 5, 79, 31, 27])
bins = [0, 20, 40, 60, 80, 100]

plt.hist(x_3, bins=bins)
plt.title('Task 3: Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
